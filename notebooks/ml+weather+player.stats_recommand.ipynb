# %%
import pandas as pd
import os
import joblib

pd.set_option('future.no_silent_downcasting', True)

# %%
import requests

API_KEY = "0943842962317c345fa1bc34ac6486ea"   # PI key

def get_weather(city, date):
    try:
        url = f"https://api.openweathermap.org/data/2.5/forecast?q={city}&appid={API_KEY}&units=metric"
        response = requests.get(url)
        data = response.json()


        if "list" not in data:
            return "Unknown"

        for item in data["list"]:
            if date in item["dt_txt"]:
                return item["weather"][0]["main"]

        return "Clear"   

    except:
        return "Unknown"

# %%
df = pd.read_csv("../artifacts/Ground_clean_dataset.csv")
df.columns = df.columns.str.lower().str.replace(" ", "_")

# %%
bookings = pd.read_csv("../artifacts/bookings.csv")

# %%
model = joblib.load("../artifacts/rf_model.joblib")
scaler = joblib.load("../artifacts/scaler.joblib")
model_features = joblib.load("../artifacts/model_features1.joblib")

# %%
import pandas as pd

team_stats = pd.read_csv("../artifacts/team_stats.csv")

team_stats
# Out:
#              team_name                ground_name  matches_played_  wins  \
# 0     Royal College XI         SSC Cricket Ground              NaN     7
# 1     Royal College XI         NCC Cricket Ground              NaN     5
# 2     Royal College XI       Colombo Colts Ground              NaN     4
# 3     Royal College XI  Colombo City Cricket Park              NaN     3
# 4     Royal College XI         P Sara Oval Ground              NaN     3
# ...                ...                        ...              ...   ...
# 1236       Panadura SC           De Soysa Stadium              NaN     3
# 1237       Panadura SC         SSC Cricket Ground              NaN     2
# 1238       Panadura SC         NCC Cricket Ground              NaN     1
# 1239       Panadura SC       Colombo Colts Ground              NaN     2
# 1240       Panadura SC         P Sara Oval Ground              NaN     2
#
#       matches_played
# 0               10.0
# 1                8.0
# 2                7.0
# 3                6.0
# 4                6.0
# ...              ...
# 1236             7.0
# 1237             6.0
# 1238             5.0
# 1239             5.0
# 1240             6.0
#
# [1241 rows x 5 columns]

# %%
new_data = pd.DataFrame([
# Royal College XI
["Royal College XI","SSC Cricket Ground",10,7],
["Royal College XI","NCC Cricket Ground",8,5],
["Royal College XI","Colombo Colts Ground",7,4],
["Royal College XI","Colombo City Cricket Park",6,3],
["Royal College XI","P Sara Oval Ground",6,3],
["Royal College XI","Bloomfield Cricket Ground",5,2],
["Royal College XI","De Soysa Stadium",5,2],
["Royal College XI","Panadura Public Ground",4,1],

# St Joseph's
["St. Joseph's College XI","SSC Cricket Ground",10,7],
["St. Joseph's College XI","NCC Cricket Ground",8,4],
["St. Joseph's College XI","Colombo City Cricket Park",7,3],
["St. Joseph's College XI","Colombo Colts Ground",6,2],
["St. Joseph's College XI","P Sara Oval Ground",7,3],
["St. Joseph's College XI","Bloomfield Cricket Ground",6,2],
["St. Joseph's College XI","De Soysa Stadium",6,2],

# Ananda College XI
["Ananda College XI","SSC Cricket Ground",9,5],
["Ananda College XI","NCC Cricket Ground",7,3],
["Ananda College XI","Colombo Colts Ground",8,4],
["Ananda College XI","Colombo City Cricket Park",7,3],
["Ananda College XI","P Sara Oval Ground",7,3],
["Ananda College XI","Bloomfield Cricket Ground",6,2],
["Ananda College XI","De Soysa Stadium",5,2],
["Ananda College XI","Panadura Public Ground",4,1],

# Nalanda College XI
["Nalanda College XI","SSC Cricket Ground",8,4],
["Nalanda College XI","NCC Cricket Ground",7,3],
["Nalanda College XI","Colombo Colts Ground",9,5],
["Nalanda College XI","Colombo City Cricket Park",6,2],
["Nalanda College XI","P Sara Oval Ground",7,3],
["Nalanda College XI","Bloomfield Cricket Ground",6,2],
["Nalanda College XI","De Soysa Stadium",5,2],

# St Peter's
["St. Peter's College XI","SSC Cricket Ground",7,3],
["St. Peter's College XI","NCC Cricket Ground",6,2],
["St. Peter's College XI","Colombo Colts Ground",8,4],
["St. Peter's College XI","Colombo City Cricket Park",7,3],
["St. Peter's College XI","Bloomfield Cricket Ground",6,2],
["St. Peter's College XI","P Sara Oval Ground",6,2],

# Colombo CC
["Colombo CC","SSC Cricket Ground",12,9],
["Colombo CC","NCC Cricket Ground",10,7],
["Colombo CC","Colombo Colts Ground",9,6],
["Colombo CC","P Sara Oval Ground",8,5],
["Colombo CC","Bloomfield Cricket Ground",7,4],
["Colombo CC","De Soysa Stadium",8,5],
["Colombo CC","Panadura Public Ground",7,3],
["Colombo CC","Kalutara Public Ground",6,2],

# Sinhalese SC
["Sinhalese SC","SSC Cricket Ground",15,12],
["Sinhalese SC","NCC Cricket Ground",12,8],
["Sinhalese SC","Colombo Colts Ground",10,7],
["Sinhalese SC","P Sara Oval Ground",9,6],
["Sinhalese SC","Bloomfield Cricket Ground",8,5],
["Sinhalese SC","De Soysa Stadium",9,6],
["Sinhalese SC","Panadura Public Ground",8,4],
["Sinhalese SC","Kalutara Public Ground",7,3],

# NCC Club
["NCC Club","NCC Cricket Ground",14,10],
["NCC Club","SSC Cricket Ground",10,6],
["NCC Club","Colombo Colts Ground",9,5],
["NCC Club","P Sara Oval Ground",9,5],
["NCC Club","Bloomfield Cricket Ground",8,4],
["NCC Club","De Soysa Stadium",7,3],
["NCC Club","Panadura Public Ground",6,2],

# Moratuwa SC
["Moratuwa SC","De Soysa Stadium",10,7],
["Moratuwa SC","Moratuwa University Ground",6,3],
["Moratuwa SC","Kalutara Public Ground",8,4],
["Moratuwa SC","Panadura Public Ground",7,3],
["Moratuwa SC","SSC Cricket Ground",6,3],
["Moratuwa SC","NCC Cricket Ground",5,2],
["Moratuwa SC","Colombo Colts Ground",5,2],

# Panadura SC
["Panadura SC","Panadura Public Ground",10,6],
["Panadura SC","Kalutara Public Ground",8,3],
["Panadura SC","De Soysa Stadium",7,3],
["Panadura SC","SSC Cricket Ground",6,2],
["Panadura SC","NCC Cricket Ground",5,1],
["Panadura SC","Colombo Colts Ground",5,2],
["Panadura SC","P Sara Oval Ground",6,2]

], columns=["team_name","ground_name","matches_played","wins"])

# %%
team_stats
# Out:
#              team_name                ground_name  matches_played_  wins  \
# 0     Royal College XI         SSC Cricket Ground              NaN     7
# 1     Royal College XI         NCC Cricket Ground              NaN     5
# 2     Royal College XI       Colombo Colts Ground              NaN     4
# 3     Royal College XI  Colombo City Cricket Park              NaN     3
# 4     Royal College XI         P Sara Oval Ground              NaN     3
# ...                ...                        ...              ...   ...
# 1236       Panadura SC           De Soysa Stadium              NaN     3
# 1237       Panadura SC         SSC Cricket Ground              NaN     2
# 1238       Panadura SC         NCC Cricket Ground              NaN     1
# 1239       Panadura SC       Colombo Colts Ground              NaN     2
# 1240       Panadura SC         P Sara Oval Ground              NaN     2
#
#       matches_played
# 0               10.0
# 1                8.0
# 2                7.0
# 3                6.0
# 4                6.0
# ...              ...
# 1236             7.0
# 1237             6.0
# 1238             5.0
# 1239             5.0
# 1240             6.0
#
# [1241 rows x 5 columns]

# %%
file_path = "../artifacts/team_stats.csv"
team_stats = pd.concat([team_stats, new_data], ignore_index=True)
team_stats.to_csv(file_path, index=False)

# %%
def recommend_grounds(user_features, date, team_name=None, city=None, top_n=5):

    data = df.copy()

    # make all columns lowercase 
    data.columns = data.columns.str.lower().str.replace(" ", "_")

    #  FILTER BY CITY 
    if city and "city" in data.columns:
        data = data[data["city"].str.lower() == city.lower()]

    #  TEAM PERFORMANCE 
    if team_name:
        team_data = team_stats[team_stats["team_name"] == team_name].copy()

        if not team_data.empty:
            team_data["win_rate"] = team_data["wins"] / team_data["matches_played"]

            data = data.merge(team_data, on="ground_name", how="left")

            data["win_rate"] = data["win_rate"].fillna(0).astype(float)
            data["matches_played"] = data["matches_played"].fillna(0).astype(float)

            data = data.drop_duplicates(subset=["ground_name"])
        else:
            data["win_rate"] = 0
    else:
        data["win_rate"] = 0

    # WEATHER 
    if "city" in data.columns:
        data["weather"] = data["city"].apply(lambda x: get_weather(x, date))
    else:
        data["weather"] = "unknown"

    # WEATHER SCORE 
    def weather_score(condition):
        condition = str(condition).lower()
        if "rain" in condition or "storm" in condition:
            return 0
        elif "cloud" in condition:
            return 0.7
        else:
            return 1

    data["weather_score"] = data["weather"].apply(weather_score)

    # REMOVE BOOKED GROUNDS 
    if 'bookings' in globals() and not bookings.empty:
        booked = bookings[bookings["date"] == date]["ground_name"]
        data = data[~data["ground_name"].isin(booked)]

    # ML SCORING 
    categorical_cols = ["city", "district", "province", "ground_type", "pitch"]

    # One-hot encoding
    data_encoded = pd.get_dummies(data, columns=categorical_cols)

    # Align with trained model features
    data_encoded = data_encoded.reindex(columns=model_features, fill_value=0)

    # Convert to numeric
    data_encoded = data_encoded.apply(pd.to_numeric, errors='coerce').fillna(0)

    # Scale
    X_scaled = scaler.transform(data_encoded)

    # Predict
    scores = model.predict_proba(X_scaled)[:, 1]

    # Assign ML score
    data["ml_score"] = scores

    # FINAL HYBRID SCORE
    data["final_score"] = (
        data["ml_score"] * 0.4 +
        data["win_rate"] * 0.4 +
        data["weather_score"] * 0.2
    )

    # RETURN TOP RESULTS 
    return data.sort_values(by="final_score", ascending=False).head(top_n)

# %%
# Step 1: define input
user_input = {
    "price_(lkr)": 120000,
    "lights": 1,
    "parking": 1,
    "rating": 4
}

# Step 2: call function
result = recommend_grounds(
    user_input,
    date="2026-04-10",
    team_name="Royal College XI",
    city="colombo"
)

# step 3: output
top = result.iloc[0]
alt = result.iloc[1]

print("Ground Recommendation Result\n")

print("Best Match:")
print(f"{top['ground_name']} | Weather: {top['weather']}")

if "rain" in str(top["weather"]).lower():
    print("\n Not suitable due to bad weather")

    print("\n Alternative:")
    print(f"{alt['ground_name']} | Weather: {alt['weather']}")
else:
    print("\n Suitable for play")
# Out:
# Ground Recommendation Result
#
# Best Match:
# Colombo City Cricket Park | Weather: Clear
#
#  Suitable for play

# %%
top = result.iloc[0]
alt = result.iloc[1] if len(result) > 1 else None

print("Ground Recommendation Result\n")

# Best Match
print(" Best for Match:")
print(f"Ground: {top['ground_name']}")
print(f"ML Score: {top['ml_score']:.2f}")
print(f"Win Rate: {top['win_rate']:.2f}")
print(f"Final Score: {top['final_score']:.2f}")
print(f"Weather: {top['weather']}")

# Weather check
if "rain" in str(top["weather"]).lower() or "storm" in str(top["weather"]).lower():

    print("\n Warning:")
    print("This ground is not suitable due to bad weather.")

    if alt is not None:
        print("\n Recommended Alternative:")
        print(f"Ground: {alt['ground_name']}")
        print(f"ML Score: {alt['ml_score']:.2f}")
        print(f"Win Rate: {alt['win_rate']:.2f}")
        print(f"Final Score: {alt['final_score']:.2f}")
        print(f"Weather: {alt['weather']}")

        print("\n Reason:")
        print("Better weather conditions for playing.")

else:
    print("\n This ground is suitable for play.")
# Out:
# Ground Recommendation Result
#
#  Best for Match:
# Ground: Colombo City Cricket Park
# ML Score: 0.57
# Win Rate: 0.50
# Final Score: 0.63
# Weather: Clear
#
#  This ground is suitable for play.

# %%
top = result.iloc[0]
alt = result.iloc[1]

print(" Ground Recommendation Result\n")

print(" Best Match:")
print(f"{top['ground_name']} | Weather: {top['weather']}")

if "rain" in str(top["weather"]).lower():
    print("\n Not suitable due to bad weather")

    print("\n Alternative:")
    print(f"{alt['ground_name']} | Weather: {alt['weather']}")
else:
    print("\n Suitable for play")
# Out:
#  Ground Recommendation Result
#
#  Best Match:
# Colombo City Cricket Park | Weather: Clear
#
#  Suitable for play

# %%
def run_system():
    city = input("Enter city: ").strip()
    date = input("Enter date (YYYY-MM-DD): ").strip()

    team_input = input("Enter team name (optional): ").strip()
    team_name = team_input if team_input != "" else None

    user_features = {
        "price_(lkr)": 120000,
        "rating": 4.5
    }

    # ---------------- RECOMMEND ----------------
    result = recommend_grounds(
        user_features=user_features,
        date=date,
        team_name=team_name,
        city=city,
        top_n=5
    )

    if result.empty:
        print("❌ No grounds found")
        return

    # ---------------- APPLY TEAM-BASED SCORING ----------------
    if team_name is not None:
        result["team_boost"] = result["win_rate"] * 0.2
    else:
        result["team_boost"] = 0

    # 🔥 Updated Final Score (IMPORTANT)
    result["final_score"] = (
        (result["ml_score"] * 0.5) +
        (result["win_rate"] * 0.3) +
        (result["team_boost"] * 0.2)
    )

    # Sort again after applying team influence
    result = result.sort_values(by="final_score", ascending=False).reset_index(drop=True)

    # ---------------- EXPLAIN AI FUNCTION ----------------
    def generate_explanation(row):
        reasons = []

        if row["final_score"] > 0.75:
            reasons.append("high overall score")

        if row["ml_score"] > 0.75:
            reasons.append("strong ML prediction")

        if row["win_rate"] > 0.70:
            reasons.append("good historical win rate")

        if team_name:
            reasons.append("team performance considered")

        if "clear" in str(row["weather"]).lower():
            reasons.append("clear weather conditions")

        if "cloud" in str(row["weather"]).lower():
            reasons.append("acceptable weather conditions")

        if "rain" in str(row["weather"]).lower():
            reasons.append("weather is risky")

        return ", ".join(reasons)

    # ---------------- BEST MATCH ----------------
    top = result.iloc[0]

    print("\n🎯 Ground Recommendation Result\n")

    print("⭐ Best Match:")
    print(f"Ground: {top['ground_name']}")
    print(f"ML Score: {top['ml_score']:.2f}")
    print(f"Win Rate: {top['win_rate']:.2f}")
    print(f"Final Score: {top['final_score']:.2f}")
    print(f"Weather: {top['weather']}")
    print(f"Explanation: {generate_explanation(top)}")

    # ---------------- WEATHER CHECK ----------------
    bad_weather = ["rain", "heavy rain", "storm"]
    alternatives = result.iloc[1:4]

    if any(w in str(top["weather"]).lower() for w in bad_weather):

        print("\n⚠️ Warning:")
        print("This ground is not suitable due to bad weather.\n")

        if not alternatives.empty:
            print("👉 Top 3 Best Alternative Grounds:")
            print("These are the next best options based on score and weather:\n")

            for i, (_, alt) in enumerate(alternatives.iterrows(), 1):
                print(f"\nAlternative {i}:")
                print(f"Ground: {alt['ground_name']}")
                print(f"ML Score: {alt['ml_score']:.2f}")
                print(f"Win Rate: {alt['win_rate']:.2f}")
                print(f"Final Score: {alt['final_score']:.2f}")
                print(f"Weather: {alt['weather']}")
                print(f"Explanation: {generate_explanation(alt)}")

        print("\n✅ Reason:")
        print("Better weather conditions and suitable for playing.")

    else:
        print("\n✅ This ground is suitable for play.")

    # ---------------- BOOKING ----------------
    print("\n🎯 these are the other best suitable grounds,Select a ground to book from the best options:")
    print(f"0 - {top['ground_name']}")

    for i, (_, alt) in enumerate(alternatives.iterrows(), 1):
        print(f"{i} - {alt['ground_name']}")

    choice = input("\nEnter option (0/1/2/3) or 'no': ").strip().lower()

    if choice in ["0", "1", "2", "3"]:

        import os
        import pandas as pd

        os.makedirs("artifacts", exist_ok=True)
        file_path = "artifacts/bookings.csv"

        team_name_final = team_name if team_name else "Anonymous"

        # Select ground
        if choice == "0":
            selected = top
        else:
            index = int(choice) - 1
            if index < len(alternatives):
                selected = alternatives.iloc[index]
            else:
                print("❌ Invalid selection")
                return

        # Save booking
        new_df = pd.DataFrame([{
            "ground_name": selected["ground_name"],
            "date": date,
            "booked_by": team_name_final
        }])

        if os.path.exists(file_path):
            new_df.to_csv(file_path, mode='a', header=False, index=False)
        else:
            new_df.to_csv(file_path, index=False)

        print(f"✅ Booking saved for: {selected['ground_name']}")

    elif choice == "no":
        print("❌ Booking cancelled")

    else:
        print("⚠️ Invalid input")

# %%
run_system()
# Out:
# Enter city:  galle
# Enter date (YYYY-MM-DD):  2026-10-30
# Enter team name (optional):  colombo cc
# 🎯 Ground Recommendation Result
#
# ⭐ Best Match:
# Ground: Galle Cricket Arena
# ML Score: 0.58
# Win Rate: 0.00
# Final Score: 0.29
# Weather: Clear
# Explanation: team performance considered, clear weather conditions
#
# ✅ This ground is suitable for play.
#
# 🎯 these are the other best suitable grounds,Select a ground to book from the best options:
# 0 - Galle Cricket Arena
# 1 - Galle Beachside Cricket Park
# 2 - Galle Youth Oval
# 3 - Galle Youth Cricket Park
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[23], line 1
# ----> 1 run_system()
#
# Cell In[14], line 117, in run_system()
#     114 for i, (_, alt) in enumerate(alternatives.iterrows(), 1):
#     115     print(f"{i} - {alt['ground_name']}")
# --> 117 choice = input("\nEnter option (0/1/2/3) or 'no': ").strip().lower()
#     119 if choice in ["0", "1", "2", "3"]:
#     121     import os
#
# File /opt/anaconda3/lib/python3.13/site-packages/ipykernel/kernelbase.py:1275, in Kernel.raw_input(self, prompt)
#    1273     msg = "raw_input was called, but this frontend does not support input requests."
#    1274     raise StdinNotImplementedError(msg)
# -> 1275 return self._input_request(
#    1276     str(prompt),
#    1277     self._parent_ident["shell"],
#    1278     self.get_parent("shell"),
#    1279     password=False,
#    1280 )
#
# File /opt/anaconda3/lib/python3.13/site-packages/ipykernel/kernelbase.py:1320, in Kernel._input_request(self, prompt, ident, parent, password)
#    1317 except KeyboardInterrupt:
#    1318     # re-raise KeyboardInterrupt, to truncate traceback
#    1319     msg = "Interrupted by user"
# -> 1320     raise KeyboardInterrupt(msg) from None
#    1321 except Exception:
#    1322     self.log.warning("Invalid Message:", exc_info=True)
#
# KeyboardInterrupt: Interrupted by user

# %%
print(df[df["city"].str.contains("galle", case=False, na=False)])
# Out:
#      unnamed:_0                      ground_name      city    district  \
# 116       117.0      Galle International Stadium     Galle       Galle
# 117       118.0           Galle Municipal Ground     Galle       Galle
# 118       119.0         Galle Sports Club Ground     Galle       Galle
# 119       120.0       Galle Urban Council Ground     Galle       Galle
# 206       206.0          Kegalle District Ground   Kegalle     Kegalle
# 207       207.0                Kegalle Esplanade   Kegalle     Kegalle
# 208       208.0            Kegalle Public Ground   Kegalle     Kegalle
# 209       209.0       Kegalle Sports Club Ground   Kegalle     Kegalle
# 210       210.0     Kegalle Urban Council Ground   Kegalle     Kegalle
# 390       390.0           Galle Riverside Ground     Galle       Galle
# 391       391.0         Galle Youth Cricket Park     Galle       Galle
# 392       392.0            Galle Community Field     Galle       Galle
# 393       393.0             Galle Village Ground     Galle       Galle
# 394       394.0              Galle Cricket Arena     Galle       Galle
# 395       395.0               Galle College Oval     Galle       Galle
# 396       396.0             Galle Sports Village     Galle       Galle
# 397       397.0     Galle Beachside Cricket Park     Galle       Galle
# 398       398.0                 Galle Youth Oval     Galle       Galle
# 399       399.0                 Galle Town Field     Galle       Galle
# 500       500.0  Richmond College Cricket Ground     Galle       Galle
# 501       501.0           Mahinda College Ground     Galle       Galle
# 502       502.0           Galle Municipal Ground     Galle       Galle
# 600       600.0            Kegalle Public Ground   Kegalle     Kegalle
# 601       601.0         Kegalle Municipal Ground   Kegalle     Kegalle
# 602       602.0   Kegalle Central College Ground   Kegalle     Kegalle
# 603       603.0      Kegalle Cricket Club Ground   Kegalle     Kegalle
# 604       604.0           Kegalle Sports Complex   Kegalle     Kegalle
# 625       625.0           Tangalle Public Ground  Tangalle  Hambantota
# 626       626.0             Tangalle Town Ground  Tangalle  Hambantota
# 627       627.0  Tangalle Central College Ground  Tangalle  Hambantota
# 628       628.0     Tangalle Cricket Club Ground  Tangalle  Hambantota
# 629       629.0           Tangalle Sports Ground  Tangalle  Hambantota
# 911       911.0         Kegalle Municipal Ground   Kegalle     Kegalle
#
#          province ground_type    pitch  length  width lights parking  \
# 116      Southern      Public     turf   145.0  149.0    Yes     Yes
# 117      Southern      Public  matting   124.0  100.0     No     Yes
# 118      Southern        Club     turf   141.0  150.0    Yes     Yes
# 119      Southern      Public  matting   129.0  107.0     No     Yes
# 206  Sabaragamuwa      Public  matting   119.0  112.0     No     Yes
# 207  Sabaragamuwa      Public     turf   144.0  150.0    Yes     Yes
# 208  Sabaragamuwa      Public  matting   115.0  110.0     No     Yes
# 209  Sabaragamuwa        Club     turf   139.0  143.0    Yes     Yes
# 210  Sabaragamuwa      Public  matting   125.0   96.0     No     Yes
# 390      Southern      Public     turf   139.0  143.0    Yes     Yes
# 391      Southern        Club     turf   134.0  136.0    Yes     Yes
# 392      Southern      Public  matting   121.0  115.0     No     Yes
# 393      Southern      Public  matting   114.0  109.0     No     Yes
# 394      Southern        Club     turf   147.0  148.0    Yes     Yes
# 395      Southern      School  matting   110.0  106.0     No     Yes
# 396      Southern      Public  matting   124.0  118.0     No     Yes
# 397      Southern        Club     turf   135.0  138.0    Yes     Yes
# 398      Southern        Club     turf   133.0  135.0    Yes     Yes
# 399      Southern      Public  matting   117.0  111.0     No     Yes
# 500      Southern      School     turf   132.0  135.0    Yes     Yes
# 501      Southern      School     turf   134.0  138.0    Yes     Yes
# 502      Southern      Public  matting   119.0  113.0     No     Yes
# 600  Sabaragamuwa      Public  matting   118.0  112.0     No     Yes
# 601  Sabaragamuwa      Public     turf   133.0  136.0    Yes     Yes
# 602  Sabaragamuwa      School  matting   118.0  112.0     No     Yes
# 603  Sabaragamuwa        Club     turf   134.0  138.0    Yes     Yes
# 604  Sabaragamuwa      Public     turf   135.0  139.0    Yes     Yes
# 625      Southern      Public  matting   118.0  112.0     No     Yes
# 626      Southern      Public     turf   134.0  137.0    Yes     Yes
# 627      Southern      School  matting   118.0  112.0     No     Yes
# 628      Southern        Club     turf   136.0  139.0    Yes     Yes
# 629      Southern      Public     turf   138.0  141.0    Yes     Yes
# 911  Sabaragamuwa      Public     turf   128.0  125.0    Yes     Yes
#
#     washrooms pavilion scoreboard  rooms  parking_cap.  price_(lkr)  rating
# 116       Yes      Yes        Yes    2.0         271.0     132661.0     5.0
# 117       Yes       No        Yes    1.0          13.0       6655.0     2.0
# 118       Yes      Yes        Yes    2.0         197.0     148914.0     5.0
# 119       Yes       No        Yes    1.0          19.0      10365.0     3.0
# 206       Yes       No        Yes    1.0          22.0      14953.0     3.0
# 207       Yes      Yes        Yes    2.0         224.0     142519.0     5.0
# 208       Yes       No        Yes    1.0          20.0       6427.0     2.0
# 209       Yes      Yes        Yes    2.0         126.0     158260.0     5.0
# 210       Yes       No        Yes    1.0          15.0      12415.0     3.0
# 390       Yes      Yes        Yes    2.0         250.0     161000.0     5.0
# 391       Yes      Yes        Yes    2.0         210.0     150000.0     4.0
# 392       Yes       No        Yes    1.0          31.0      10800.0     3.0
# 393       Yes       No         No    1.0          24.0       7600.0     2.0
# 394       Yes      Yes        Yes    3.0         285.0     172000.0     5.0
# 395       Yes      Yes         No    2.0          36.0      25000.0     3.0
# 396       Yes       No        Yes    1.0          29.0      10200.0     3.0
# 397       Yes      Yes        Yes    2.0         240.0     158000.0     5.0
# 398       Yes      Yes        Yes    2.0         205.0     146000.0     4.0
# 399       Yes       No         No    1.0          26.0       8500.0     2.0
# 500       Yes      Yes        Yes    2.0         160.0      37000.0     4.0
# 501       Yes      Yes        Yes    2.0         150.0      36000.0     4.0
# 502       Yes       No         No    1.0          45.0      17000.0     3.0
# 600       Yes       No         No    1.0          50.0      17000.0     3.0
# 601       Yes      Yes        Yes    2.0         160.0      35000.0     4.0
# 602       Yes      Yes         No    2.0          60.0      20000.0     3.0
# 603       Yes      Yes        Yes    2.0         170.0      36000.0     4.0
# 604       Yes      Yes        Yes    2.0         180.0      38000.0     4.0
# 625       Yes       No         No    1.0          45.0      17000.0     3.0
# 626       Yes      Yes        Yes    2.0         160.0      34000.0     4.0
# 627       Yes      Yes         No    2.0          60.0      20000.0     3.0
# 628       Yes      Yes        Yes    2.0         170.0      36000.0     4.0
# 629       Yes      Yes        Yes    2.0         180.0      38000.0     4.0
# 911       Yes      Yes        Yes    2.0         130.0      36000.0     4.0

# %%
print(df.shape)
# Out:
# (1038, 18)

# %%
print(df[df["ground_name"].str.contains("Galle", case=False, na=False)][
    ["ground_name", "rating", "price_(lkr)"]
])
# Out:
#                            ground_name  rating  price_(lkr)
# 38    Bakamuna Atharagallewa MV Ground     3.0      17164.0
# 73          Colombo (Galle Face) Green     2.0      13861.0
# 84            Colombo Galle Face Green     3.0      14614.0
# 116        Galle International Stadium     5.0     132661.0
# 117             Galle Municipal Ground     2.0       6655.0
# 118           Galle Sports Club Ground     5.0     148914.0
# 119         Galle Urban Council Ground     3.0      10365.0
# 129  General Balagalle Cricket Stadium     5.0     172125.0
# 206            Kegalle District Ground     3.0      14953.0
# 207                  Kegalle Esplanade     5.0     142519.0
# 208              Kegalle Public Ground     2.0       6427.0
# 209         Kegalle Sports Club Ground     5.0     158260.0
# 210       Kegalle Urban Council Ground     3.0      12415.0
# 390             Galle Riverside Ground     5.0     161000.0
# 391           Galle Youth Cricket Park     4.0     150000.0
# 392              Galle Community Field     3.0      10800.0
# 393               Galle Village Ground     2.0       7600.0
# 394                Galle Cricket Arena     5.0     172000.0
# 395                 Galle College Oval     3.0      25000.0
# 396               Galle Sports Village     3.0      10200.0
# 397       Galle Beachside Cricket Park     5.0     158000.0
# 398                   Galle Youth Oval     4.0     146000.0
# 399                   Galle Town Field     2.0       8500.0
# 502             Galle Municipal Ground     3.0      17000.0
# 600              Kegalle Public Ground     3.0      17000.0
# 601           Kegalle Municipal Ground     4.0      35000.0
# 602     Kegalle Central College Ground     3.0      20000.0
# 603        Kegalle Cricket Club Ground     4.0      36000.0
# 604             Kegalle Sports Complex     4.0      38000.0
# 625             Tangalle Public Ground     3.0      17000.0
# 626               Tangalle Town Ground     4.0      34000.0
# 627    Tangalle Central College Ground     3.0      20000.0
# 628       Tangalle Cricket Club Ground     4.0      36000.0
# 629             Tangalle Sports Ground     4.0      38000.0
# 911           Kegalle Municipal Ground     4.0      36000.0
